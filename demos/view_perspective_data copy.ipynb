# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# Directory containing perspective images
data_dir = "../perspective_data/perspective_data_linear_fits_radial"

# Get the first 10 .npy files (sorted for consistency)
fits_files = sorted([f for f in os.listdir(data_dir) if f.endswith(".fits")])[:10]

print("Files to display:")
for fname in fits_files:
    print(fname)
# Out:
# Files to display:
# output_tensor_000_hgln_-180.0_hglt_-90.0.fits
# output_tensor_001_hgln_-180.0_hglt_-70.0.fits
# output_tensor_002_hgln_-180.0_hglt_-50.0.fits
# output_tensor_003_hgln_-180.0_hglt_-30.0.fits
# output_tensor_004_hgln_-180.0_hglt_-10.0.fits
# output_tensor_005_hgln_-180.0_hglt_10.0.fits
# output_tensor_006_hgln_-180.0_hglt_30.0.fits
# output_tensor_007_hgln_-180.0_hglt_50.0.fits
# output_tensor_008_hgln_-180.0_hglt_70.0.fits
# output_tensor_009_hgln_-180.0_hglt_90.0.fits

# %%
# Plot the first 10 FITS images
fig, axes = plt.subplots(2, 5, figsize=(20, 8))
axes = axes.flatten()

for i, fname in enumerate(fits_files):
    img = fits.getdata(os.path.join(data_dir, fname))
    ax = axes[i]
    im = ax.imshow(img, origin='lower', cmap='inferno')
    ax.set_title(fname.replace(".fits", ""))
    ax.axis('off')
    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

plt.tight_layout()
plt.show()
